# %%
pip install nltk scikit-learn
# Out:
# Collecting nltk
#   Downloading nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: scikit-learn in c:\users\divesh\appdata\roaming\python\python310\site-packages (1.6.1)
# Requirement already satisfied: click in c:\users\divesh\.conda\envs\edu\lib\site-packages (from nltk) (8.3.3)
# Requirement already satisfied: joblib in c:\users\divesh\appdata\roaming\python\python310\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\divesh\.conda\envs\edu\lib\site-packages (from nltk) (2026.4.4)
# Requirement already satisfied: tqdm in c:\users\divesh\appdata\roaming\python\python310\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\divesh\.conda\envs\edu\lib\site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\divesh\appdata\roaming\python\python310\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\divesh\appdata\roaming\python\python310\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: colorama in c:\users\divesh\appdata\roaming\python\python310\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.9.4-py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.6 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 2.8 MB/s  0:00:00
# Installing collected packages: nltk
# Successfully installed nltk-3.9.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag

from sklearn.feature_extraction.text import TfidfVectorizer

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Divesh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Divesh\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Divesh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Divesh\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Divesh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Divesh\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
text = "Natural Language Processing is very useful for text analytics and machine learning."

# %%
tokens = word_tokenize(text)

print("Tokens:")
print(tokens)
# Out:
# Tokens:
# ['Natural', 'Language', 'Processing', 'is', 'very', 'useful', 'for', 'text', 'analytics', 'and', 'machine', 'learning', '.']

# %%
pos = pos_tag(tokens)

print("POS Tags:")
print(pos)
# Out:
# POS Tags:
# [('Natural', 'JJ'), ('Language', 'NNP'), ('Processing', 'NNP'), ('is', 'VBZ'), ('very', 'RB'), ('useful', 'JJ'), ('for', 'IN'), ('text', 'NN'), ('analytics', 'NNS'), ('and', 'CC'), ('machine', 'NN'), ('learning', 'NN'), ('.', '.')]

# %%
stop_words = set(stopwords.words('english'))

filtered_words = []

for word in tokens:
    if word.lower() not in stop_words:
        filtered_words.append(word)

print("After Stop Words Removal:")
print(filtered_words)
# Out:
# After Stop Words Removal:
# ['Natural', 'Language', 'Processing', 'useful', 'text', 'analytics', 'machine', 'learning', '.']

# %%
ps = PorterStemmer()

stemmed_words = []

for word in filtered_words:
    stemmed_words.append(ps.stem(word))

print("Stemmed Words:")
print(stemmed_words)
# Out:
# Stemmed Words:
# ['natur', 'languag', 'process', 'use', 'text', 'analyt', 'machin', 'learn', '.']

# %%
lemmatizer = WordNetLemmatizer()

lemmatized_words = []

for word in filtered_words:
    lemmatized_words.append(lemmatizer.lemmatize(word))

print("Lemmatized Words:")
print(lemmatized_words)
# Out:
# Lemmatized Words:
# ['Natural', 'Language', 'Processing', 'useful', 'text', 'analytics', 'machine', 'learning', '.']

# %%
documents = [
    "Machine learning is fun",
    "Machine learning is useful",
    "Text analytics uses machine learning"
]

# %%
vectorizer = TfidfVectorizer()

tfidf_matrix = vectorizer.fit_transform(documents)

print("Terms:")
print(vectorizer.get_feature_names_out())

print("\nTF-IDF Matrix:")
print(tfidf_matrix.toarray())
# Out:
# Terms:
# ['analytics' 'fun' 'is' 'learning' 'machine' 'text' 'useful' 'uses']
#
# TF-IDF Matrix:
# [[0.         0.66283998 0.50410689 0.39148397 0.39148397 0.
#   0.         0.        ]
#  [0.         0.         0.50410689 0.39148397 0.39148397 0.
#   0.66283998 0.        ]
#  [0.52004008 0.         0.         0.30714405 0.30714405 0.52004008
#   0.         0.52004008]]
